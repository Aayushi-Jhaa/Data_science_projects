# %% [markdown]
# <a href="https://colab.research.google.com/github/AashRoxx/Data_science_projects/blob/main/Covid_analysis/Covid_19_analysis_India.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read file

covid19India_df = pd.read_csv('covid_19_india.csv')
covid19India_df
# Out:
#          Sno        Date     Time  ...    Cured Deaths Confirmed
# 0          1  2020-01-30  6:00 PM  ...        0      0         1
# 1          2  2020-01-31  6:00 PM  ...        0      0         1
# 2          3  2020-02-01  6:00 PM  ...        0      0         2
# 3          4  2020-02-02  6:00 PM  ...        0      0         3
# 4          5  2020-02-03  6:00 PM  ...        0      0         3
# ...      ...         ...      ...  ...      ...    ...       ...
# 18105  18106  2021-08-11  8:00 AM  ...   638410   3831    650353
# 18106  18107  2021-08-11  8:00 AM  ...    77811    773     80660
# 18107  18108  2021-08-11  8:00 AM  ...   334650   7368    342462
# 18108  18109  2021-08-11  8:00 AM  ...  1685492  22775   1708812
# 18109  18110  2021-08-11  8:00 AM  ...  1506532  18252   1534999
#
# [18110 rows x 9 columns]

# %%
covid19India_df.shape
# Out:
# (18110, 9)

# %%
covid19India_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Date                      18110 non-null  object
#  2   Time                      18110 non-null  object
#  3   State/UnionTerritory      18110 non-null  object
#  4   ConfirmedIndianNational   18110 non-null  object
#  5   ConfirmedForeignNational  18110 non-null  object
#  6   Cured                     18110 non-null  int64
#  7   Deaths                    18110 non-null  int64
#  8   Confirmed                 18110 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %%
covid19India_df.head()
# Out:
#    Sno        Date     Time  ... Cured Deaths Confirmed
# 0    1  2020-01-30  6:00 PM  ...     0      0         1
# 1    2  2020-01-31  6:00 PM  ...     0      0         1
# 2    3  2020-02-01  6:00 PM  ...     0      0         2
# 3    4  2020-02-02  6:00 PM  ...     0      0         3
# 4    5  2020-02-03  6:00 PM  ...     0      0         3
#
# [5 rows x 9 columns]

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Full dataset")

# Line chart  
sns.lineplot(data=covid19India_df)

# %%
# State wise Observations
covid19India_df['State/UnionTerritory'].value_counts().sort_values()
# Out:
# Maharashtra***                                1
# Karanataka                                    1
# Daman & Diu                                   1
# Madhya Pradesh***                             1
# Himanchal Pradesh                             1
# Dadra and Nagar Haveli                        2
# Bihar****                                     2
# Unassigned                                    3
# Cases being reassigned to states             60
# Telangana                                   102
# Lakshadweep                                 244
# Telengana                                   426
# Sikkim                                      445
# Nagaland                                    452
# Dadra and Nagar Haveli and Daman and Diu    461
# Meghalaya                                   485
# Tripura                                     492
# Arunachal Pradesh                           496
# Jharkhand                                   498
# Assam                                       498
# Goa                                         504
# Andaman and Nicobar Islands                 504
# Mizoram                                     505
# Manipur                                     506
# Bihar                                       506
# Madhya Pradesh                              508
# Himachal Pradesh                            508
# Gujarat                                     510
# Chhattisgarh                                511
# Chandigarh                                  511
# West Bengal                                 512
# Puducherry                                  512
# Odisha                                      514
# Uttarakhand                                 515
# Andhra Pradesh                              518
# Maharashtra                                 520
# Karnataka                                   520
# Jammu and Kashmir                           521
# Punjab                                      521
# Tamil Nadu                                  523
# Ladakh                                      523
# Uttar Pradesh                               526
# Haryana                                     526
# Rajasthan                                   527
# Delhi                                       528
# Kerala                                      560
# Name: State/UnionTerritory, dtype: int64

# %%
#higher number of entries
covid19India_df_Haryana = covid19India_df[covid19India_df['State/UnionTerritory']=='Haryana']
covid19India_df_Haryana
covid19India_df_Kerala = covid19India_df[covid19India_df['State/UnionTerritory']=='Kerala']
covid19India_df_Kerala
covid19India_df_WestBengal = covid19India_df[covid19India_df['State/UnionTerritory']=='West Bengal']
covid19India_df_WestBengal
# Out:
#          Sno        Date     Time  ...    Cured Deaths Confirmed
# 208      209  2020-03-18  6:00 PM  ...        0      0         1
# 227      228  2020-03-19  6:00 PM  ...        0      0         1
# 247      248  2020-03-20  6:00 PM  ...        0      0         2
# 269      270  2020-03-21  6:00 PM  ...        0      0         3
# 292      293  2020-03-22  6:00 PM  ...        0      0         4
# ...      ...         ...      ...  ...      ...    ...       ...
# 17965  17966  2021-08-07  8:00 AM  ...  1503535  18202   1532379
# 18001  18002  2021-08-08  8:00 AM  ...  1504326  18217   1533128
# 18037  18038  2021-08-09  8:00 AM  ...  1505089  18229   1533803
# 18073  18074  2021-08-10  8:00 AM  ...  1505808  18240   1534360
# 18109  18110  2021-08-11  8:00 AM  ...  1506532  18252   1534999
#
# [512 rows x 9 columns]

# %%
plt.figure(figsize=(10,6))
plt.title("Haryana dataset")
sns.lineplot(data=covid19India_df_Haryana)

# %%
plt.figure(figsize=(10,6))
plt.title("Kerala dataset")
sns.lineplot(data=covid19India_df_Kerala)

# %%
plt.figure(figsize=(10,6))
plt.title("WestBengal dataset")
sns.lineplot(data=covid19India_df_WestBengal)

# %%
covid19India_df_Telengana = covid19India_df[covid19India_df['State/UnionTerritory']=='Telengana']
covid19India_df_Telengana
plt.figure(figsize=(10,6))
plt.title(" dataset Telengana")
sns.lineplot(data=covid19India_df_Telengana)

# %%
covid19India_df_by_State = covid19India_df.groupby('State/UnionTerritory')[['Cured','Deaths' ,'Confirmed']].sum().reset_index()
covid19India_df_by_State
# Out:
#                         State/UnionTerritory       Cured    Deaths   Confirmed
# 0                Andaman and Nicobar Islands     1848286     27136     1938498
# 1                             Andhra Pradesh   370426530   2939367   392432753
# 2                          Arunachal Pradesh     6588149     26799     7176907
# 3                                      Assam    92678680    638323    99837011
# 4                                      Bihar   125122902   1093466   132231166
# 5                                  Bihar****     1402468     18881     1430909
# 6           Cases being reassigned to states           0         0      345565
# 7                                 Chandigarh    10117035    147694    10858627
# 8                               Chhattisgarh   151609364   2063920   163776262
# 9                     Dadra and Nagar Haveli       20352         8       20722
# 10  Dadra and Nagar Haveli and Daman and Diu     1841750      1014     1938632
# 11                               Daman & Diu           0         0           2
# 12                                     Delhi   273419887   4943294   287227765
# 13                                       Goa    26027201    447801    28240159
# 14                                   Gujarat   132487127   2219448   143420082
# 15                                   Haryana   126585342   1502799   134347285
# 16                          Himachal Pradesh    27501110    491348    30033289
# 17                         Himanchal Pradesh      200040      3507      204516
# 18                         Jammu and Kashmir    53297341    839694    58117726
# 19                                 Jharkhand    58034506    748641    62111994
# 20                                Karanataka     2821491     36197     2885238
# 21                                 Karnataka   441844360   6053762   485970693
# 22                                    Kerala   420174235   1888177   458906023
# 23                                    Ladakh     3758960     45804     4054293
# 24                               Lakshadweep      820925      3908      915784
# 25                            Madhya Pradesh   126724997   1777752   135625265
# 26                         Madhya Pradesh***      780735     10506      791656
# 27                               Maharashtra  1018765039  23737432  1121491467
# 28                            Maharashtra***     6000911    130753     6229596
# 29                                   Manipur    11230568    173056    12617943
# 30                                 Meghalaya     6537909    101950     7355969
# 31                                   Mizoram     2384602      9791     2984732
# 32                                  Nagaland     4519526     58460     5041742
# 33                                    Odisha   150923455    790814   160130533
# 34                                Puducherry    18483117    312155    20065891
# 35                                    Punjab    91458159   2785594    99949702
# 36                                 Rajasthan   150356820   1473089   162369656
# 37                                    Sikkim     2747214     53150     3186799
# 38                                Tamil Nadu   404095807   5916658   431928644
# 39                                 Telangana    57488245    349648    60571979
# 40                                 Telengana    64666267    400427    69990668
# 41                                   Tripura    12976846    150342    14050250
# 42                                Unassigned           0         0         161
# 43                             Uttar Pradesh   291479351   4143450   312625843
# 44                               Uttarakhand    48362741    986001    53140414
# 45                               West Bengal   247515102   3846989   263107876

# %%
plt.figure(figsize=(10,6))
plt.title("Cured")
sns.barplot(x=covid19India_df_by_State.index, y=covid19India_df_by_State['Cured'])
plt.ylabel("Cured")
# Out:
# Text(0, 0.5, 'Cured')

# %%
plt.figure(figsize=(10,6))
plt.title("Confirmed")
sns.barplot(x=covid19India_df_by_State.index, y=covid19India_df_by_State['Confirmed'])
plt.ylabel("Confirmed")
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
plt.figure(figsize=(10,6))
plt.title("Deaths")
sns.barplot(x=covid19India_df_by_State.index, y=covid19India_df_by_State['Deaths'])
plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %% [markdown]
# EDA on StatewiseTestingDetails

# %%
#read file
fname = 'StatewiseTestingDetails.csv'
testing_df = pd.read_csv('StatewiseTestingDetails.csv')

# %%
testing_df.shape
# Out:
# (16336, 5)

# %%
testing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16336 entries, 0 to 16335
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          16336 non-null  object
#  1   State         16336 non-null  object
#  2   TotalSamples  16336 non-null  float64
#  3   Negative      6969 non-null   object
#  4   Positive      5662 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 638.2+ KB

# %%
testing_df.head(5)
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
plt.figure(figsize=(20,5))
plt.title("Full dataset")
sns.lineplot(data=testing_df)

# %%
# State wise Observations
testing_df.State.value_counts().sort_values()
# Out:
# Dadra and Nagar Haveli and Daman and Diu    170
# Lakshadweep                                 195
# Ladakh                                      294
# Manipur                                     406
# Meghalaya                                   409
# Sikkim                                      413
# Telangana                                   419
# Tripura                                     447
# Andaman and Nicobar Islands                 453
# Mizoram                                     465
# Assam                                       469
# Arunachal Pradesh                           477
# Puducherry                                  478
# Chandigarh                                  479
# Chhattisgarh                                482
# Goa                                         483
# Nagaland                                    484
# Jharkhand                                   484
# Gujarat                                     487
# Himachal Pradesh                            488
# Maharashtra                                 488
# Andhra Pradesh                              488
# Bihar                                       489
# Delhi                                       489
# Jammu and Kashmir                           489
# Uttar Pradesh                               490
# Punjab                                      491
# Tamil Nadu                                  491
# Karnataka                                   491
# Rajasthan                                   491
# Uttarakhand                                 491
# Madhya Pradesh                              492
# Odisha                                      492
# Haryana                                     492
# West Bengal                                 493
# Kerala                                      497
# Name: State, dtype: int64

# %%
testing_df_Haryana = testing_df[testing_df.State=='Haryana']
testing_df_Haryana
testing_df_Kerala = testing_df[testing_df.State=='Kerala']
testing_df_Kerala
testing_df_WestBengal = testing_df[testing_df.State=='West Bengal']
testing_df_WestBengal
# Out:
#              Date        State  TotalSamples Negative  Positive
# 15843  2020-04-01  West Bengal         659.0      568      37.0
# 15844  2020-04-04  West Bengal        1042.0      NaN       NaN
# 15845  2020-04-06  West Bengal        1301.0      NaN       NaN
# 15846  2020-04-07  West Bengal        1487.0      NaN       NaN
# 15847  2020-04-09  West Bengal        1889.0      NaN       NaN
# ...           ...          ...           ...      ...       ...
# 16331  2021-08-06  West Bengal    15999961.0      NaN       NaN
# 16332  2021-08-07  West Bengal    16045662.0      NaN       NaN
# 16333  2021-08-08  West Bengal    16092192.0      NaN       NaN
# 16334  2021-08-09  West Bengal    16122345.0      NaN       NaN
# 16335  2021-08-10  West Bengal    16162814.0      NaN       NaN
#
# [493 rows x 5 columns]

# %%
plt.figure(figsize=(10,6))
plt.title("Haryana dataset")
sns.lineplot(data=testing_df_Haryana)

# %%
plt.figure(figsize=(10,6))
plt.title("Kerala dataset")
sns.lineplot(data=testing_df_Kerala)

# %%
plt.figure(figsize=(10,6))
plt.title("West Bengal dataset")
sns.lineplot(data=testing_df_WestBengal)

# %%
#states with lower testing
testing_df_Dadra = testing_df[testing_df.State=='Dadra and Nagar Haveli and Daman and Diu']
testing_df_Dadra
testing_df_Lakshadweep = testing_df[testing_df.State=='Lakshadweep']
testing_df_Lakshadweep
testing_df_Ladakh = testing_df[testing_df.State=='Ladakh']
testing_df_Ladakh
# Out:
#             Date   State  TotalSamples Negative  Positive
# 7907  2020-04-13  Ladakh         618.0      NaN      17.0
# 7908  2020-04-14  Ladakh         760.0      615      17.0
# 7909  2020-04-15  Ladakh         820.0      657      18.0
# 7910  2020-04-16  Ladakh         917.0      695      18.0
# 7911  2020-04-19  Ladakh         991.0      797      18.0
# ...          ...     ...           ...      ...       ...
# 8196  2021-08-05  Ladakh      446614.0      NaN       NaN
# 8197  2021-08-06  Ladakh      448829.0      NaN       NaN
# 8198  2021-08-07  Ladakh      450438.0      NaN       NaN
# 8199  2021-08-08  Ladakh      451917.0      NaN       NaN
# 8200  2021-08-09  Ladakh      454086.0      NaN       NaN
#
# [294 rows x 5 columns]

# %%
plt.figure(figsize=(10,6))
plt.title("Dadra and Nagar Haveli dataset")
sns.lineplot(data=testing_df_Dadra)

# %%
plt.figure(figsize=(10,6))
plt.title("Lakshadweep dataset")
sns.lineplot(data=testing_df_Lakshadweep)

# %%
plt.figure(figsize=(10,6))
plt.title("Ladakh dataset")
sns.lineplot(data=testing_df_Ladakh)

# %%
testing_df_by_State = testing_df.groupby('State')[['TotalSamples','Positive' ,'Negative']].sum().reset_index()
testing_df_by_State
# Out:
#                                        State  TotalSamples    Positive
# 0                Andaman and Nicobar Islands  8.747008e+07   1763591.0
# 1                             Andhra Pradesh  4.967773e+09   3859260.0
# 2                          Arunachal Pradesh  1.636096e+08     51245.0
# 3                                      Assam  2.853509e+09   2065991.0
# 4                                      Bihar  7.392796e+09   1859345.0
# 5                                 Chandigarh  9.974705e+07     59195.0
# 6                               Chhattisgarh  1.863129e+09    467857.0
# 7   Dadra and Nagar Haveli and Daman and Diu  6.324267e+06    169010.0
# 8                                      Delhi  4.310596e+09   6848173.0
# 9                                        Goa  1.979067e+08    266181.0
# 10                                   Gujarat  4.623914e+09   8009517.0
# 11                                   Haryana  2.056736e+09   2830153.0
# 12                          Himachal Pradesh  4.271429e+08    119494.0
# 13                         Jammu and Kashmir  1.960284e+09    977615.0
# 14                                 Jharkhand  2.053512e+09  51696495.0
# 15                                 Karnataka  6.773248e+09   4701197.0
# 16                                    Kerala  4.269006e+09  79723175.0
# 17                                    Ladakh  4.213546e+07     89027.0
# 18                               Lakshadweep  2.001715e+07         0.0
# 19                            Madhya Pradesh  2.298458e+09   9584080.0
# 20                               Maharashtra  7.334574e+09  96901583.0
# 21                                   Manipur  1.855130e+08    101501.0
# 22                                 Meghalaya  1.251595e+08     33904.0
# 23                                   Mizoram  8.460259e+07     19785.0
# 24                                  Nagaland  5.183817e+07     90682.0
# 25                                    Odisha  2.965651e+09   2214458.0
# 26                                Puducherry  2.383986e+08   6287323.0
# 27                                    Punjab  2.026576e+09    960287.0
# 28                                 Rajasthan  2.520540e+09   2445076.0
# 29                                    Sikkim  2.979406e+07     17644.0
# 30                                Tamil Nadu  6.711189e+09  12772604.0
# 31                                 Telangana  3.422977e+09   3855373.0
# 32                                   Tripura  2.467333e+08  12630766.0
# 33                             Uttar Pradesh  1.138818e+10   2743971.0
# 34                               Uttarakhand  9.792698e+08    350257.0
# 35                               West Bengal  3.051636e+09   3487431.0

# %%
plt.figure(figsize=(10,6))
plt.title("TotalSamples")
sns.barplot(x=testing_df_by_State.index, y=testing_df_by_State['TotalSamples'])
plt.ylabel("TotalSamples")
# Out:
# Text(0, 0.5, 'TotalSamples')

# %%
plt.figure(figsize=(10,6))
plt.title("Positive Samples")
sns.barplot(x=testing_df_by_State.index, y=testing_df_by_State['Positive'])
plt.ylabel("Positive Samples")
# Out:
# Text(0, 0.5, 'Positive Samples')

# %% [markdown]
# EDA on StateWise Vaccine details

# %%
#read file
fname = 'covid_vaccine_statewise.csv'
vaccine_df = pd.read_csv('covid_vaccine_statewise.csv')

# %%
vaccine_df.shape
# Out:
# (7845, 24)

# %%
vaccine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7845 entries, 0 to 7844
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Updated On                           7845 non-null   object
#  1   State                                7845 non-null   object
#  2   Total Doses Administered             7621 non-null   float64
#  3   Sessions                             7621 non-null   float64
#  4    Sites                               7621 non-null   float64
#  5   First Dose Administered              7621 non-null   float64
#  6   Second Dose Administered             7621 non-null   float64
#  7   Male (Doses Administered)            7461 non-null   float64
#  8   Female (Doses Administered)          7461 non-null   float64
#  9   Transgender (Doses Administered)     7461 non-null   float64
#  10   Covaxin (Doses Administered)        7621 non-null   float64
#  11  CoviShield (Doses Administered)      7621 non-null   float64
#  12  Sputnik V (Doses Administered)       2995 non-null   float64
#  13  AEFI                                 5438 non-null   float64
#  14  18-44 Years (Doses Administered)     1702 non-null   float64
#  15  45-60 Years (Doses Administered)     1702 non-null   float64
#  16  60+ Years (Doses Administered)       1702 non-null   float64
#  17  18-44 Years(Individuals Vaccinated)  3733 non-null   float64
#  18  45-60 Years(Individuals Vaccinated)  3734 non-null   float64
#  19  60+ Years(Individuals Vaccinated)    3734 non-null   float64
#  20  Male(Individuals Vaccinated)         160 non-null    float64
#  21  Female(Individuals Vaccinated)       160 non-null    float64
#  22  Transgender(Individuals Vaccinated)  160 non-null    float64
#  23  Total Individuals Vaccinated         5919 non-null   float64
# dtypes: float64(22), object(2)
# memory usage: 1.4+ MB

# %%
vaccine_df.head()
# Out:
#    Updated On  ... Total Individuals Vaccinated
# 0  16/01/2021  ...                      48276.0
# 1  17/01/2021  ...                      58604.0
# 2  18/01/2021  ...                      99449.0
# 3  19/01/2021  ...                     195525.0
# 4  20/01/2021  ...                     251280.0
#
# [5 rows x 24 columns]
# Warning: Total number of columns (24) exceeds max_columns (20) limiting to first (20) columns.

# %%
vaccine_df['State'].unique()
#y
#len(vaccine_df['State'].unique())
# Out:
# array(['India', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
# Set the width and height of the figure
plt.figure(figsize=(60,6))

# Add title
plt.title("Male Individuals Vaccinated")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=vaccine_df.index, y=vaccine_df['Male(Individuals Vaccinated)'] )

# Add label for vertical axis
plt.ylabel("Male(Individuals Vaccinated)")
# Out:
# Text(0, 0.5, 'Male(Individuals Vaccinated)')

# %%
plt.figure(figsize=(60,6))

plt.title("Female(Individuals Vaccinated)")

sns.barplot(x=vaccine_df.index, y=vaccine_df['Female(Individuals Vaccinated)'] )

plt.ylabel("Female(Individuals Vaccinated)")
# Out:
# Text(0, 0.5, 'Female(Individuals Vaccinated)')

# %%
plt.figure(figsize=(60,6))

plt.title("Transgender(Individuals Vaccinated)")

sns.barplot(x=vaccine_df.index, y=vaccine_df['Transgender(Individuals Vaccinated)'] )

plt.ylabel("Transgender(Individuals Vaccinated)")
# Out:
# Text(0, 0.5, 'Transgender(Individuals Vaccinated)')

# %%
# State wise Observations
vaccine_df.State.value_counts().sort_values()
# Out:
# Chhattisgarh                                212
# Jammu and Kashmir                           212
# Rajasthan                                   212
# Gujarat                                     212
# Nagaland                                    212
# Uttar Pradesh                               212
# Tripura                                     212
# Uttarakhand                                 212
# Arunachal Pradesh                           212
# Dadra and Nagar Haveli and Daman and Diu    212
# Punjab                                      212
# Kerala                                      212
# Maharashtra                                 212
# Goa                                         212
# India                                       212
# Tamil Nadu                                  212
# Haryana                                     212
# Karnataka                                   212
# Assam                                       212
# Sikkim                                      212
# Manipur                                     212
# West Bengal                                 212
# Himachal Pradesh                            212
# Meghalaya                                   212
# Odisha                                      212
# Bihar                                       212
# Puducherry                                  212
# Mizoram                                     212
# Jharkhand                                   212
# Chandigarh                                  212
# Madhya Pradesh                              212
# Lakshadweep                                 212
# Andhra Pradesh                              212
# Telangana                                   212
# Ladakh                                      212
# Andaman and Nicobar Islands                 212
# Delhi                                       213
# Name: State, dtype: int64

# %%
vaccine_df_by_State = vaccine_df.groupby('State')[['Male(Individuals Vaccinated)','Female(Individuals Vaccinated)' ,'Transgender(Individuals Vaccinated)']].sum().reset_index()
vaccine_df_by_State
# Out:
#                                        State  ...  Transgender(Individuals Vaccinated)
# 0                Andaman and Nicobar Islands  ...                                  0.0
# 1                             Andhra Pradesh  ...                                  0.0
# 2                          Arunachal Pradesh  ...                                  0.0
# 3                                      Assam  ...                                  0.0
# 4                                      Bihar  ...                                  0.0
# 5                                 Chandigarh  ...                                  0.0
# 6                               Chhattisgarh  ...                                  0.0
# 7   Dadra and Nagar Haveli and Daman and Diu  ...                                  0.0
# 8                                      Delhi  ...                                  0.0
# 9                                        Goa  ...                                  0.0
# 10                                   Gujarat  ...                                  0.0
# 11                                   Haryana  ...                                  0.0
# 12                          Himachal Pradesh  ...                                  0.0
# 13                                     India  ...                            1979287.0
# 14                         Jammu and Kashmir  ...                                  0.0
# 15                                 Jharkhand  ...                                  0.0
# 16                                 Karnataka  ...                                  0.0
# 17                                    Kerala  ...                                  0.0
# 18                                    Ladakh  ...                                  0.0
# 19                               Lakshadweep  ...                                  0.0
# 20                            Madhya Pradesh  ...                                  0.0
# 21                               Maharashtra  ...                                  0.0
# 22                                   Manipur  ...                                  0.0
# 23                                 Meghalaya  ...                                  0.0
# 24                                   Mizoram  ...                                  0.0
# 25                                  Nagaland  ...                                  0.0
# 26                                    Odisha  ...                                  0.0
# 27                                Puducherry  ...                                  0.0
# 28                                    Punjab  ...                                  0.0
# 29                                 Rajasthan  ...                                  0.0
# 30                                    Sikkim  ...                                  0.0
# 31                                Tamil Nadu  ...                                  0.0
# 32                                 Telangana  ...                                  0.0
# 33                                   Tripura  ...                                  0.0
# 34                             Uttar Pradesh  ...                                  0.0
# 35                               Uttarakhand  ...                                  0.0
# 36                               West Bengal  ...                                  0.0
#
# [37 rows x 4 columns]
